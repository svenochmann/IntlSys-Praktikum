# %% [markdown]
# # Projekt 5: Sammeln, Plotten und bereinigen der Daten

# %% [markdown]
# ## Wichtig
# Ab diesem Abschnitt müssen sie das Board vollständig verkabelt haben und alle Komponenten müssen ansteuerbar sein. Sollte es Probleme geben, gehen Sie die letzten Projektübungen durch.

# %% [markdown]
# ## Übung 1: Scannen

# %% [markdown]
# Suchen Sie verschiedene Gegenstände (mindestens 2, am besten 3), die sich über die Plattform drehen lassen. Die Gegenstände sollten sich in ihrer Geometrie unterscheiden lassen. Zum Beispiel ein Würfel und ein Zylinder.
# Mögliche Beispiele zum Scannen sind folgende drei Gegenstände:
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# <ul>
#     <li>Scannen Sie die Gegenstände mehrmals ein!</li>
#     <li>Überlegen Sie sich, wie oft sie die Gegenstände scannen wollen.</li>
#     <li>Was sollten Sie beim Scannen beachten?</li>
#     <li>Welche Probleme könnten zu viele oder zu wenige Daten verursachen?</li>
#     <li>Speichern Sie die gescannten Daten in einem file ab, um es für die weitere Verarbeitung zu nutzen</li>
#     <li>Entscheiden Sie, wie Sie die Daten sammeln und speichern</li>
# </ul>
# Wenn sie die Daten gespeichert haben, finden Sie diese unter Datei-Öffen-MicroPython Device:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200"/>
# </div>

# %% [markdown]
# Öffnen Sie die Datei, um sie dann auf ihrem Rechner abzuspeichern. Der Hintergrund für den umständlichen Weg liegt darin, dass die Daten auf dem ESP32 gespeichert werden und nicht direkt auf dem Rechner. Sie können auch eine Funktion progammieren, die diesen Vorgang automatisch durchführt.

# %% [markdown]
# ## Übung 2: Plotten der Daten

# %% [markdown]
# Nachdem Sie die Daten gespeichert haben, öffnen Sie über eine beliebige IDE ein Python Kernel, um die Daten zu laden.
# <ul>
# <li>Versuchen Sie einen Überblick über alle gesammelten Daten zu erhalten</li>
# <li>Welche Methoden eignen sich besonders gut für eine Übersicht?</li>
# <li>Nutzen Sie Diagramme zur Visualisierung. Überlegen Sie sich, welche Diagramme für das Projekt am besten geeignet sind</li>
# <li>Versuchen Sie die Ergebnisse zu interpretieren. Was fällt Ihnen auf? Welche Probleme sind vielleicht aufgetreten?</li>
# </ul>

# %% [markdown]
# Beispiele zur Visualisierung
# <div>
# <img src="attachment:image.png" width="800"/>
# </div>

# %% [markdown]
# ## Übung 3: Bereinigung der Daten

# %% [markdown]
# <ul>
# <li>Bereinigen Sie die Daten soweit wie nötig!</li>
# <li>Sollten Fehlerhaften Daten oder Ausreißer vorhanden sein, überlegen Sie sich eine Möglichkeit damit umzugehen</li>
# <li>Begutachten sie den Wertebereich der Daten. Gibt es eine Möglichkeit, ohne Informationsverlust den Wertebereich zu minimieren?</li>
# </ul>
